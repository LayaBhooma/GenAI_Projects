# %%
#%pip install python-dotenv

import os
from dotenv import load_dotenv
load_dotenv(override=True, dotenv_path="../.env.local")
my_api_key = os.getenv("OPENAI_API_KEY")
print(f"API_KEY: {my_api_key}")
# Out:
# API_KEY: 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

# %%
#%pip install openai

# %%
from urllib import response
from openai import OpenAI
client = OpenAI(api_key=my_api_key)



while True:
    prompt = input("What is your question, (or type 'exit' to quit): ") 
    if prompt.lower() in ['exit', 'quit']:
        break
    else:    
        response = client.chat.completions.create( 

            model="gpt-5-nano", #"gpt-5-turbo", #"gpt-5", #"gpt-5-mini", #"gpt-5-nano"
            messages=[
                {"role": "system", "content": "You are a helpful assistant. Answer the user's questions concisely."},
                {"role": "user", "content": prompt}
                # {"role": "user", "content": f"Here is the context: \n\ {context} \n\. \n\n Now, answer the question: {prompt}")
            ]
        )
        print (response.choices[0].message.content)
# Out:
# SFO is San Francisco International Airport, located in San Mateo County, California, USA — about 13 miles (21 km) south of downtown San Francisco. Want directions or a map?
# The Bay Area usually refers to the San Francisco Bay Area in Northern California, USA. It surrounds the San Francisco Bay and includes nine counties: Alameda, Contra Costa, Marin, Napa, San Francisco, San Mateo, Santa Clara, Solano, and Sonoma. Major cities include San Francisco, Oakland, and San Jose. If you meant a different Bay Area, tell me the country or area.
# Do you mean the San Francisco Bay Area in Northern California, USA?
#
# - It’s the region around the San Francisco Bay, north of the Monterey Bay.
# - Counties often included: Alameda, Contra Costa, Marin, Napa, San Francisco, San Mateo, Santa Clara, Solano, Sonoma.
# - Major cities: San Francisco, Oakland, San Jose, Berkeley, Palo Alto, Fremont, Santa Rosa, Napa, etc.
#
# If you meant a different Bay Area, tell me which one and I’ll help.
# Which place are you asking about? The cost of living varies a lot by city and country.
#
# If you tell me the specific location (and whether you’ll be living solo or with family, and any budget expectations), I can give you a quick estimate of typical monthly costs (rent, utilities, groceries, transportation, etc.) and how it compares to your current location.
# You’re right about the confusion. I don’t automatically remember past chats. In this chat, I can use the messages you’ve sent here. If you want me to keep something in mind for this session, tell me and I’ll reference it. What history topic would you like to discuss?
# The Bay Area is a big, diverse region around San Francisco Bay. It’s known for:
# - Mild overall climate with strong microclimates (SF-coast is cool and windy, inland areas can be much warmer)
# - A strong tech/entrepreneurship scene, great food, and scenic spots (Golden Gate Bridge, Napa, Muir Woods)
# - High housing costs and often heavy traffic
#
# If you want something specific, tell me: current weather, traffic updates, cost of living, places to visit, or tips forSF/Oakland/San Jose. I can look up live details if you’d like.
# Which place are you referring to? If you tell me the city (and whether you’re single, with a partner, or a family), I can give you a rough monthly budget and typical rent ranges.
#
# In general:
# - Big cities tend to be more expensive, especially for housing.
# - Smaller towns or suburban/rural areas are usually cheaper.
# - Key costs to check: rent (often the largest share), utilities (electricity, heating), groceries, transportation, health insurance/medical, internet, and taxes.
#
# If you want quick numbers, I can look up current estimates for your target city (via Numbeo/Expatistan) once you share the location.
