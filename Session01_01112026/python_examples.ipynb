# %% [markdown]
# ##This is my first ipynb code

# %%
print("Hello AI World")
name= input("What is your name? ")
score= (input("What is your score? "))
print(f"Hello, {name}. Your score is {score}.")
# Out:
# Hello AI World
# Hello, N. Your score is 25.

# %%
question = input("Press Enter your questions or type 'exit' to quit...")
print(f"Great question!You asked: {question}")
# Out:
# Great question!You asked: tt

# %%
while True:
    user_input = input("How can I help you?")
    if user_input.lower() == 'exit':
        print("Exiting chatbot. GoodBye")
        break
    else:
        print(f"Great question!You asked: {user_input}")
        print(f"Chatbot response to: {user_input}")
# Out:
# Exiting chatbot. GoodBye
