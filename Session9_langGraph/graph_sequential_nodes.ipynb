# %%
# python -m venv .venv
# source .venv/bin/activate  # On Windows, use `.venv\Scripts\activate`
# %pip install langgraph
# Out:
# Requirement already satisfied: langgraph in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (1.0.8)
# Requirement already satisfied: langchain-core>=0.1 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from langgraph) (1.2.13)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from langgraph) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from langgraph) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from langgraph) (0.3.6)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from langgraph) (2.12.5)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from langchain-core>=0.1->langgraph) (0.4.55)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from langchain-core>=0.1->langgraph) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from langchain-core>=0.1->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from langchain-core>=0.1->langgraph) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from langchain-core>=0.1->langgraph) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from langchain-core>=0.1->langgraph) (0.14.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.7)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from pydantic>=2.7.4->langgraph) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: anyio in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.12.1)
# Requirement already satisfied: certifi in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nirma\training\genai_projects\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.6.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langgraph.graph import StateGraph, START, END

# %%
def node_a_agent(dict):
    # Simulate some processing
    # Do something useful here
    print("Agent A is running")
    return {}

def node_b_agent(dict):
    # Simulate some processing
    # Do something useful here
    print("Agent B is running")
    return {}


builder = StateGraph(dict)

builder.add_node("Agent_A", node_a_agent)
builder.add_node("Agent_B", node_b_agent)


builder.add_edge(START, "Agent_A")
builder.add_edge("Agent_A", "Agent_B")
builder.add_edge("Agent_B", END)



graph = builder.compile()

# %%
# %pip install grandalf
# Out:
# Collecting grandalf
#   Using cached grandalf-0.8-py3-none-any.whl.metadata (1.7 kB)
# Collecting pyparsing (from grandalf)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Using cached grandalf-0.8-py3-none-any.whl (41 kB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, grandalf
# Successfully installed grandalf-0.8 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# --- Display as ASCII ---
print(graph.get_graph().draw_ascii())
# Out:
# +-----------+
# | __start__ |
# +-----------+
#       *
#       *
#       *
#  +---------+
#  | Agent_A |
#  +---------+
#       *
#       *
#       *
#  +---------+
#  | Agent_B |
#  +---------+
#       *
#       *
#       *
#  +---------+
#  | __end__ |
#  +---------+

# %%
# Invoke the graph with an empty initial state
initial_state = {}
graph.invoke(initial_state)
# Out:
# Agent A is running
# Agent B is running
# {}
